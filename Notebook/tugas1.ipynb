# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('house_price_data_2.csv')
df.shape
# Out:
# (21616, 21)

# %%
df = df.drop(["id"], axis=1)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159800e+04  21598.000000  21598.000000  21598.000000  2.159800e+04
# mean   5.402803e+05      3.373136      2.115775   2080.281091  1.509917e+04
# std    3.673674e+05      0.926325      0.769004    918.104411  4.141169e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.619000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068475e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21598.000000  21598.000000  21598.000000  21598.000000  21598.000000
# mean       1.494074      0.007547      0.234281      3.409853      7.657885
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().any()
#df.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
# Out:
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.duplicated()
df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21611    False
# 21612    False
# 21613    False
# 21614    False
# 21615    False
# Length: 21616, dtype: bool

# %%
df = df.drop(["id"], axis=1)

# %%
# df = df.drop(["id"], axis=1)
df=df[df['bedrooms'] > 0]
df=df[df['bathrooms'] > 0]
df=df[df['sqft_living'] > 100]

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159800e+04  21598.000000  21598.000000  21598.000000  2.159800e+04
# mean   5.402803e+05      3.373136      2.115775   2080.281091  1.509917e+04
# std    3.673674e+05      0.926325      0.769004    918.104411  4.141169e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.619000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068475e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21598.000000  21598.000000  21598.000000  21598.000000  21598.000000
# mean       1.494074      0.007547      0.234281      3.409853      7.657885
# ...

# %%
df.shape
# Out:
# (21598, 20)

# %%
df=df[df['sqft_living'] > 100]

# %%
count, bin_edges = np.histogram(df['bedrooms'])
df['bedrooms'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk bedrooms')
plt.ylabel('Frekuensi')
plt.xlabel('bedrooms')
plt.show()

# %%
count, bin_edges = np.histogram(df['bathrooms'])
df['bathrooms'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk bathrooms')
plt.ylabel('Frekuensi')
plt.xlabel('bathrooms')
plt.show()

# %%
count, bin_edges = np.histogram(df['sqft_living'])
df['sqft_living'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk sqft_living')
plt.ylabel('Frekuensi')
plt.xlabel('sqft_living')
plt.show()

# %%
count, bin_edges = np.histogram(df['sqft_lot'])
df['sqft_lot'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk sqft_lot')
plt.ylabel('Frekuensi')
plt.xlabel('sqft_lot')
plt.show()

# %%
count, bin_edges = np.histogram(df['floors'])
df['floors'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk floors')
plt.ylabel('Frekuensi')
plt.xlabel('floors')
plt.show()

# %%
count, bin_edges = np.histogram(df['waterfront'])
df['waterfront'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk waterfront')
plt.ylabel('Frekuensi')
plt.xlabel('waterfront')
plt.show()

# %%
count, bin_edges = np.histogram(df['view'])
df['view'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk view')
plt.ylabel('Frekuensi')
plt.xlabel('view')
plt.show()

# %%
count, bin_edges = np.histogram(df['condition'])
df['condition'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk condition')
plt.ylabel('Frekuensi')
plt.xlabel('condition')
plt.show()

# %%
count, bin_edges = np.histogram(df['grade'])
df['grade'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk grade')
plt.ylabel('Frekuensi')
plt.xlabel('grade')
plt.show()

# %%
count, bin_edges = np.histogram(df['sqft_above'])
df['sqft_above'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk sqft_above')
plt.ylabel('Frekuensi')
plt.xlabel('sqft_above')
plt.show()

# %%
count, bin_edges = np.histogram(df['sqft_basement'])
df['sqft_basement'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk sqft_basement')
plt.ylabel('Frekuensi')
plt.xlabel('sqft_basement')
plt.show()

# %%
count, bin_edges = np.histogram(df['yr_built'])
df['yr_built'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk yr_built')
plt.ylabel('Frekuensi')
plt.xlabel('yr_built')
plt.xticks(rotation=60)
plt.show()

# %%
count, bin_edges = np.histogram(df['yr_renovated'])
df['yr_renovated'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk yr_renovated')
plt.ylabel('Frekuensi')
plt.xlabel('yr_renovated')
plt.xticks(rotation=60)
plt.show()

# %%
count, bin_edges = np.histogram(df['sqft_lot15'])
df['sqft_lot15'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk sqft_lot15')
plt.ylabel('Frekuensi')
plt.xlabel('sqft_lot15')
plt.xticks(rotation=60)
plt.show()

# %%
count, bin_edges = np.histogram(df['zipcode'])
df['zipcode'].plot(kind = 'hist', xticks = bin_edges, color = "skyblue")
plt.title('Histogram untuk zipcode')
plt.ylabel('Frekuensi')
plt.xlabel('zipcode')
plt.xticks(rotation=60)
plt.show()

# %%
binwidth = 1
plt.hist(df['bedrooms'], bins=range(min(df['bedrooms']), max(df['bedrooms']) + binwidth, binwidth))
plt.show()

# %%
df['bathrooms'].value_counts().to_frame()
# Out:
#       bathrooms
# 2.50       5377
# 1.00       3852
# 1.75       3048
# 2.25       2047
# 2.00       1930
# 1.50       1445
# 2.75       1185
# 3.00        753
# 3.50        731
# 3.25        589
# 3.75        155
# 4.00        136
# 4.50        100
# 4.25         79
# 0.75         71
# 4.75         23
# 5.00         21
# 5.25         13
# 5.50         10
# 1.25          9
# 6.00          6
# 0.50          4
# 5.75          4
# 6.75          2
# 8.00          2
# 6.25          2
# 6.50          2
# 7.50          1
# 7.75          1

# %%
df['grade'].value_counts().to_frame()
# Out:
#     grade
# 7    8975
# 8    6065
# 9    2615
# 6    2038
# 10   1134
# 11    399
# 5     242
# 12     89
# 4      27
# 13     13
# 3       1

# %%
korelasi = df.corr()
sns.heatmap(data=korelasi, cmap="YlGnBu", linecolor="black", linewidths=0.5)
----------6utyutyutyutyutyutyudertert-----------tyghutyughjdsfsdfsdf-tyutyu--[----------ererteertertert]

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053336
# long             0.022035
# condition        0.036015
# yr_built         0.054024
# sqft_lot15       0.082869
# sqft_lot         0.089880
# yr_renovated     0.126430
# floors           0.256834
# waterfront       0.266397
# lat              0.306743
# bedrooms         0.308831
# sqft_basement    0.323818
# view             0.397375
# bathrooms        0.525933
# sqft_living15    0.585264
# sqft_above       0.605380
# grade            0.667957
# sqft_living      0.701930
# price            1.000000
# Name: price, dtype: float64

# %%
sns.regplot(df['sqft_living'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['grade'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
def add(a, b):
    return a+5, b+5

result = add(3, 2)
print(result)
# Out:
# (8, 7)

# %%
sns.regplot(df['sqft_above'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['sqft_living15'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['zipcode'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.lmplot(x="grade", y="price", data= df, fit_reg= False, palette="Set3")

# %%
df["bathrooms"].value_counts().plot(kind='bar')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.countplot(df.bedrooms,order=df['bedrooms'].value_counts().index)
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
# df=df[df['bedrooms'] < 9]
# sns.lmplot(x="bedrooms", y="price", data= df, fit_reg= False, palette="Set3")

# %%
(df["price"].values < 0).any()
(df["bedrooms"].values < 0).any()
(df["bathrooms"].values < 0).any()
(df["sqft_living"].values < 0).any()
(df["sqft_lot"].values < 0).any()
(df["sqft_above"].values < 0).any()
(df["grade"].values < 0).any()
(df["condition"].values < 0).any()
# Out:
# False

# %%
import statistics


bedroomsCheck = df.loc[(df["bedrooms"] == 2)]

price = bedroomsCheck["price"]
bathrooms2 = bedroomsCheck["bathrooms"]

bathroomCheck = bathrooms2.values
priceV = price.values
x = statistics.mean(bathroomCheck)
y = statistics.mean(priceV)
for j in range(len(bedroomsCheck)):
    a1 = a1 + ((bathroomCheck[j]-x) * (priceV[j]-y))
    temp = temp + ((bathroomCheck[j]-x) ** 2) + ((priceV[j]-y) ** 2)
a1 = a1/temp
a0 = y - (a1*x)

def predictC (a1, a0, bath):
    price = a1 + (a0 * bath)
    return price

# %%
print("Nilai Prediksi =", round(predictC(a1,a0,1)))
# Out:
# Nilai Prediksi = 401311

# %%
sns.regplot(df['grade'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['floors'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['waterfront'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['lat'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['long'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['condition'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.scatterplot(df['bedrooms'], df['price'])
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['bathrooms'], df['price'])
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.scatterplot(df['bathrooms'], df['price'])
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['bedrooms'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['floors'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['waterfront'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['condition'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['view'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['lat'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['long'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['sqft_lot'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['sqft_basement'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['yr_built'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')

# %%
sns.regplot(df['sqft_lot15'], df['price'], line_kws={"color": "red"})
sns.set(rc={'figure.figsize':(5, 5)})
plt.title("Regression Plot")
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Regression Plot')
